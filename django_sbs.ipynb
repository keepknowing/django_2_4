# %% [markdown]
# django steps
#
#
# mkdir 'folder name project'
# cd to folder
# python3 -m venv 'venv_name'
# source .venv/bin/activate
#
# pip install django
#
# 'code .' note: executed in venv and python will be 3.10 and do not need activate venv in vs code openned.
#
#
# django-admin startproject 'name_project' .   ! this dot will create the main project folder in same dir
#
#   settings > can update language
#
# python manage.py runserver :-> to test application
#
#
# need model to makemigrations
#
# 1. python manage.py migrate :->  to create files migrations but not in database
#
# needs ...
# 2. python manage.py migrate :-> to real migrate and create all necessary
#
# create superuser
#
# no novo app... apos criacao, makemigrations e migrate models ... podemos ir em admin e importar o model
#  admin.site.register(Pessoa) :-> no paranteses a class criada no models

# %% [markdown]
# ### create venv
#     * python3 -m venv .venv
#     * install requirements.yxy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### create super user with

# %% [markdown]
# ### urls.py

# %% [markdown]
# urls.py    urlpatterns e add novo path

# %% [markdown]
# ### views.py

# %% [markdown]
# ### startapp

# %% [markdown]
# ### models
#  * class to describe instances, database, busyness model ...

# %% [markdown]
# ### migrate
#
#  * python manage.py makemigrations <!-- cria os arquivos de migracao -->
#  * python manage.py migrate   <!-- faz a migracao e envia para o banco>

# %% [markdown]
# ### register model in admin.py
#
# * admin.py
#      * from . import models

# %% [markdown]
# ### templates
#     need be created beside manage.py

# %% [markdown]
# * go settings.py and insert path to templates

# %% [markdown]
# ### static

# %% [markdown]
# 1. create folder static
# 2. insert STATICFILES_DIR in settings
# 3. create css styles like style.css in static folder
# 4. in html file in templates insert in start ...
#     * {% load static %}
#     * a row with <link rel="stylesheet" href="{% static 'myfirst.css' %}">
